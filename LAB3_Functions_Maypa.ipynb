# %%
# [CELL 1] STUDENT CONFIGURATION

LAST_NAME = "Maypa"
STUDENT_ID = "TUPM-25-0357"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:, SEED_DIGIT")
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Maypa
# Seed Digit:, SEED_DIGIT
# Digit Sum: 22
# Surname Length: 5

# %%
# [CELL 2] FUNCTIONAL ENCAPSULATION

def greet():
    print("=" * 40)
    print(f"System Intatilized for: {Maypa}")
    print("=" * 40)

def identify_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
    greet()
    print("Identity Code:", identity_code())

# %%
# [CELL 3] LEGB VALIDATION

global_value = "ID_SUM"

def scope_test():
    global_value = "SEED_DIGIT"
    print("Inside function:", global_value)

scope_test()
print("Outside function:", global_value)
# Out:
# Inside function: SEED_DIGIT
# Outside function: ID_SUM

# %%
# [CELL 4] PARAMETRIC PROCESSING

def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round(average,2))

    for k, v in info.items():
        print(f"{k}: {v}")

    
avg = user_summary(
    f"{"Maypa"} Academic Report", 
    7 * 10, 
    22 % 100, 5 * 5, 
    id='TUPM-25-0357', 
    surname='Maypa'
)
# Out:
# === Maypa Academic Report ===
# Scores: (70, 22, 25)
# Total: 117
# Average: 39.0
# id: TUPM-25-0357
# surname: Maypa

# %%
# [CELL 5] RETURN MECHANISM

def compute_area(radius):
    return 3.1416 * radius**2

area = compute_area(7 + 2)
print("Computed Area:", round(area,2))
# Out:
# Computed Area: 254.47

# %%
# [CELL 6] SAFE CALCULATOR

def safe_calculator(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculation Result:", safe_calculator(22, 7))
# Out:
# Calculation Result: 3.142857142857143

# %%
# [CELL 7] RECURSION

def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial Result:", factorial(7))
# Out:
# Factorial Result: 5040

# %%
# [CELL 8] STRING RECURSION

def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])

print("Reversed Surname:", reverse('Maypa'.upper()))
# Out:
# Reversed Surname: APYAM

# %%
# [CELL 9] DECORATOR

def logger(func):
    def wrapper(*args, **kwargs):
        print("Executing:", func.__name__)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply(x, y):
    return x * y

print("Multiplication:", multiply(7, 5))
# Out:
# Executing: multiply
# Multiplication: 35

# %%
# [CELL 10] LAMBDA FUNCTIONS

data = list(range(1, 7 + 10))
squared = list(map(lambda x: x**2, data))

print("Squared Data:", squared)
# Out:
# Squared Data: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256]
